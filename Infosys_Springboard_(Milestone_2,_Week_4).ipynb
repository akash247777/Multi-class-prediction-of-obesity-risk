# %% [markdown]
# #**Milestone 2 (Week 4)**

# %% [markdown]
# ##Mounting the Google Drive for loading the dataset, importing Python libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path='/content/drive/MyDrive/preprocessed_data.csv'

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   frequent_consumption_of_high_caloric_food  \
# 0                                       yes
# 1                                       yes
# 2                                       yes
# 3                                       yes
# 4                                       yes
#
#    frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 0                                2.000000              2.983297
# 1                                2.000000              3.000000
# ...

# %%
df.iloc[-5:]
# Out:
#         id  Gender        Age    Height      Weight  \
# 4994  4994    Male  19.684891  1.838441   85.312639
# 4995  4995    Male  16.000000  1.700000   71.000000
# 4996  4996    Male  19.000000  1.800000   85.000000
# 4997  4997    Male  19.946244  1.603435   45.000000
# 4998  4998  Female  20.519916  1.716497  129.013178
#
#      family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 4994                            yes                                       yes
# 4995                            yes                                       yes
# 4996                             no                                        no
# 4997                            yes                                       yes
# 4998                            yes                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4994                                2.971588                   3.0
# ...

# %% [markdown]
# ##Installing PyCaret

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 43.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 25.4 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *

# %% [markdown]
# ##Setting up PyCaret using various parameters

# %%
s=setup(data=df, target='obesity_level',
        session_id=123,
        normalize=True,
        feature_selection=True,
        polynomial_features=True,
        experiment_name='obesity_prediction',
        remove_multicollinearity=True,
        multicollinearity_threshold=0.95)
# Out:
# <style type="text/css">
# #T_e2a01_row10_col1, #T_e2a01_row16_col1, #T_e2a01_row18_col1, #T_e2a01_row20_col1, #T_e2a01_row22_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e2a01" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2a01_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e2a01_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2a01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2a01_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e2a01_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e2a01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2a01_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e2a01_row1_col1" class="data row1 col1" >obesity_level</td>
#     </tr>
# ...

# %% [markdown]
# ##Comparing models based on the last setup

# %% [markdown]
# ##Creating a list of the top 3 most efficient models on the given dataset

# %%
top_models = compare_models(
    include=['gbc', 'lightgbm', 'rf', 'xgboost', 'et', 'knn', 'dt', 'lr'],   # Include specific models
    fold=5,                            # Number of folds for cross-validation
    n_select=3,                        # Number of top models to select
    verbose=True,                      # Print detailed output
    budget_time=900,                   # Maximum time for model selection in seconds
    sort='precision'
)
# Out:
# <style type="text/css">
# #T_1487d th {
#   text-align: left;
# }
# ...

# %%
top_models
# Out:
# [GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='log_loss', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_samples_leaf=1,
#                             min_samples_split=2, min_weight_fraction_leaf=0.0,
#                             n_estimators=100, n_iter_no_change=None,
#                             random_state=123, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='sqrt',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_samples_leaf=1,
# ...

# %% [markdown]
# ##Blending the models in the top_models to create an even better model, increasing the performance

# %%
# Blend top models
blender = blend_models(estimator_list=top_models, fold=5)

# Finalize the best model
final_model = finalize_model(blender)

# Print the best model
print(final_model)
# Out:
# <style type="text/css">
# #T_434a4_row5_col0, #T_434a4_row5_col1, #T_434a4_row5_col2, #T_434a4_row5_col3, #T_434a4_row5_col4, #T_434a4_row5_col5, #T_434a4_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_434a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_434a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_434a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_434a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_434a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_434a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_434a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_434a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
final_model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Age', 'Weight', 'Height'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=na...
#                                                               importance_type='split',
#                                                               learning_rate=0.1,
# ...

# %% [markdown]
# ##Getting configuration of train_df and test_df

# %%
train_df = get_config('X_train')
test_df = get_config('X_test')

# %%
test_df.head()
# Out:
#         id  Gender        Age    Height      Weight  \
# 4713  4713    Male  22.705772  1.854706  121.657982
# 4950  4950  Female  18.000000  1.590000   52.000000
# 1925  1925  Female  18.000000  1.650000   80.000000
# 1447  1447  Female  21.232658  1.751067  133.843033
# 4369  4369  Female  25.951979  1.608469  102.093224
#
#      family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 4713                            yes                                       yes
# 4950                             no                                       yes
# 1925                            yes                                       yes
# 1447                            yes                                       yes
# 4369                            yes                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4713                                2.819934              1.163666
# ...

# %%
#train_df=df.sample(frac=0.7, random_state=42)
#test_df=df.drop(train_df.index)

# %% [markdown]
# ##Making prediction using the previous best model

# %%
df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   frequent_consumption_of_high_caloric_food  \
# 0                                       yes
# 1                                       yes
# 2                                       yes
# 3                                       yes
# 4                                       yes
#
#    frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 0                                2.000000              2.983297
# 1                                2.000000              3.000000
# ...

# %% [markdown]
# ##Predicting using the final model

# %%
predictions=predict_model(final_model, data=test_df)
predictions.head()
# Out:
#         id  Gender        Age    Height      Weight  \
# 4713  4713    Male  22.705772  1.854706  121.657982
# 4950  4950  Female  18.000000  1.590000   52.000000
# 1925  1925  Female  18.000000  1.650000   80.000000
# 1447  1447  Female  21.232658  1.751067  133.843033
# 4369  4369  Female  25.951979  1.608469  102.093224
#
#      family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 4713                            yes                                       yes
# 4950                             no                                       yes
# 1925                            yes                                       yes
# 1447                            yes                                       yes
# 4369                            yes                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4713                                2.819934              1.163666
# ...

# %%
# Define the path to save the CSV file in Google Drive
csv_path = '/content/drive/My Drive/predictions(Milestone_2,Week 3).csv'  # Adjust the file path as needed

# Save the DataFrame to a CSV file
predictions.to_csv(csv_path)

print(f"Predictions saved to {csv_path}")
# Out:
# Predictions saved to /content/drive/My Drive/predictions(Milestone_2,Week 3).csv

# %% [markdown]
# ##Saving the trained model

# %%
save_model(final_model, '/content/drive/My Drive/final_model_week3_Infosys_Springboard')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['id', 'Age', 'Height', 'Weight',
#                                               'frequency_of_consumption_of_vegetables',
#                                               'number_of_main_meals',
#                                               'consumption_of_water_daily',
#                                               'physical_activity...
#                                                                importance_type='split',
#                                                                learning_rate=0.1,
# ...

# %% [markdown]
# ##Loading the model saved previously

# %%
loaded_model = load_model('/content/drive/My Drive/final_model_week3_Infosys_Springboard')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
train_df = get_config('X_train')
test_df = get_config('X_test')

# %% [markdown]
# ##Predicting using the loaded model gives the same result

# %%
predict_model(loaded_model, data=test_df).head()
# Out:
#         id  Gender        Age    Height      Weight  \
# 4713  4713    Male  22.705772  1.854706  121.657982
# 4950  4950  Female  18.000000  1.590000   52.000000
# 1925  1925  Female  18.000000  1.650000   80.000000
# 1447  1447  Female  21.232658  1.751067  133.843033
# 4369  4369  Female  25.951979  1.608469  102.093224
#
#      family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 4713                            yes                                       yes
# 4950                             no                                       yes
# 1925                            yes                                       yes
# 1447                            yes                                       yes
# 4369                            yes                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4713                                2.819934              1.163666
# ...

# %%
loaded_model
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['id', 'Age', 'Height', 'Weight',
#                                              'frequency_of_consumption_of_vegetables',
#                                              'number_of_main_meals',
#                                              'consumption_of_water_daily',
#                                              'physic...
#                                                               importance_type='split',
#                                                               learning_rate=0.1,
#                                                               max_depth=-1,
# ...

# %% [markdown]
# ##Metrics analyzed during model comparison

# %%
get_metrics()
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc              <function accuracy_score at 0x7bb2a5edc430>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa         <function cohen_kappa_score at 0x7bb2a5edc790>
# mcc           <function matthews_corrcoef at 0x7bb2a5edc9d0>
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# ...

# %% [markdown]
# ##Data visualization

# %% [markdown]
# ####ROC Curve plot

# %%
#Default ROC curve obtained for the first model (GBC) in the top_models list
plot_model(top_models[0])

# %% [markdown]
# ####Classification Report plot

# %%
plot_model(top_models[0], plot='class_report')

# %% [markdown]
# ####Validation Curve plot

# %%
plot_model(top_models[0], plot='vc')

# %% [markdown]
# ####Confusion Matrix plot

# %%
plot_model(top_models[0], plot='confusion_matrix')

# %% [markdown]
# ####Class Prediction error plot

# %%
#Error analysis of the best model (Gradient Boosting Classifier) in the top_models list
plot_model(top_models[0], plot='error')

# %% [markdown]
# ####Precision Recall plot for blended model

# %%
plot_model(loaded_model, plot='pr')

# %% [markdown]
# ##Loading test data

# %%
test_modified=pd.read_csv('/content/drive/MyDrive/test_modified (given for testing).csv')

# %%
test_modified.head()
# Out:
#      id  Gender        Age    Height     Weight  \
# 0  4999  Female  31.274628  1.670000  71.602622
# 1  5000  Female  18.947102  1.647811  85.079589
# 2  5001  Female  37.524551  1.548178  80.000000
# 3  5002    Male  20.000000  1.770000  70.000000
# 4  5003    Male  34.389679  1.733875  84.557797
#
#   family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 0                            yes                                       yes
# 1                            yes                                       yes
# 2                            yes                                       yes
# 3                            yes                                       yes
# 4                            yes                                       yes
#
#    frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 0                                2.843709              1.599464
# 1                                2.911749              3.000000
# ...

# %%
test_modified.shape
# Out:
# (5017, 17)

# %% [markdown]
# ##Data cleaning on test data

# %%
test_modified[test_modified.isna().any(axis=1) | (test_modified== ' ').any(axis=1)]
# Out:
#         id  Gender   Age  Height  Weight family_history_with_overweight  \
# 4979  9978    Male  23.0    1.77   105.0                            yes
# 4981  9980  Female  21.0    1.59    60.0                            yes
#
#      frequent_consumption_of_high_caloric_food  \
# 4979                                       yes
# 4981                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4979                                     2.0                   3.0
# 4981                                     2.0                   1.0
#
#      consumption_of_food_between_meals SMOKE  consumption_of_water_daily  \
# 4979                               NaN    no                         3.0
# 4981                         Sometimes    no                         NaN
#
#      calories_consumption_monitoring  physical_activity_frequency  \
# 4979                              no                          3.0
# ...

# %%
test_modified['consumption_of_water_daily']=test_modified['consumption_of_water_daily'].fillna(test_modified['consumption_of_water_daily'].mean())

# %%
test_modified[test_modified.isna().any(axis=1) | (test_modified== ' ').any(axis=1)]
# Out:
#         id Gender   Age  Height  Weight family_history_with_overweight  \
# 4979  9978   Male  23.0    1.77   105.0                            yes
#
#      frequent_consumption_of_high_caloric_food  \
# 4979                                       yes
#
#       frequency_of_consumption_of_vegetables  number_of_main_meals  \
# 4979                                     2.0                   3.0
#
#      consumption_of_food_between_meals SMOKE  consumption_of_water_daily  \
# 4979                               NaN    no                         3.0
#
#      calories_consumption_monitoring  physical_activity_frequency  \
# 4979                              no                          3.0
#
#       time_using_technology_devices consumption_of_alcohol  \
# 4979                            0.0              Sometimes
#
#         transportation_used
# 4979  Public_Transportation

# %%
test_modified.dropna(inplace=True)

# %%
test_modified.shape
# Out:
# (5016, 17)

# %%
test_modified[test_modified.isna().any(axis=1) | (test_modified== ' ').any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, Gender, Age, Height, Weight, family_history_with_overweight, frequent_consumption_of_high_caloric_food, frequency_of_consumption_of_vegetables, number_of_main_meals, consumption_of_food_between_meals, SMOKE, consumption_of_water_daily, calories_consumption_monitoring, physical_activity_frequency, time_using_technology_devices, consumption_of_alcohol, transportation_used]
# Index: []

# %%
test_modified.duplicated().sum()
# Out:
# 17

# %%
test_modified=test_modified.drop_duplicates()

# %%
test_modified.shape
# Out:
# (4999, 17)

# %% [markdown]
# ##Predicting the label for test data

# %%
test_predictions=predict_model(loaded_model, data=test_modified)

# %%
test_predictions
# Out:
#         id  Gender        Age    Height      Weight  \
# 0     4999  Female  31.274628  1.670000   71.602623
# 1     5000  Female  18.947102  1.647811   85.079590
# 2     5001  Female  37.524551  1.548178   80.000000
# 3     5002    Male  20.000000  1.770000   70.000000
# 4     5003    Male  34.389679  1.733875   84.557800
# ...    ...     ...        ...       ...         ...
# 4995  9994    Male  18.000000  1.750000   86.000000
# 4996  9995    Male  23.096354  1.819867  105.428627
# 4997  9996    Male  22.884722  1.806947  105.696358
# 4998  9997    Male  18.000000  1.680000   68.000000
# 4999  9998    Male  25.920738  1.823755  118.669907
#
#      family_history_with_overweight frequent_consumption_of_high_caloric_food  \
# 0                               yes                                       yes
# 1                               yes                                       yes
# 2                               yes                                       yes
# ...

# %% [markdown]
# ##Saving the predictions to a file in Google Drive

# %%
test_predictions.to_csv('/content/drive/My Drive/test_predictions(Milestone 2, Week 4).csv')
